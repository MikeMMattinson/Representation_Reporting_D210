# %% [markdown]
# # install python

# %% [markdown]
# After installing python, update environment variable call "pythonpath"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# then, add %PythonPath% to top of System Path

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # python updates

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 14.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0
#     Uninstalling pip-22.0:
#       Successfully uninstalled pip-22.0
# ...

# %%
# !python -m pip install --upgrade pandas

# %% [markdown]
# # install jupyter and ipython

# %%
# !python -m pip install jupyter
# Out:
# ...
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# ...
#   Using cached ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# ...
#   Using cached jupyter_console-6.4.0-py3-none-any.whl (22 kB)
# ...
#      -------------------------------------- 120.2/120.2 KB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 13.0 MB/s eta 0:00:00
# ...
#   Using cached jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# ...
#      ---------------------------------------- 65.7/65.7 KB ? eta 0:00:00
# ...

# %% [raw]
# !python -m pip install ipython

# %% [markdown]
# # Setup Kernel

# %% [markdown]
# https://queirozf.com/entries/jupyter-kernels-how-to-add-change-remove

# %%
# !ipython kernel install --name "py39_venv" --user
# Out:
# Installed kernelspec py39_venv in C:\Users\mikem\AppData\Roaming\jupyter\kernels\py39_venv

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   py39_venv    C:\Users\mikem\AppData\Roaming\jupyter\kernels\py39_venv
#   python3      D:\Python39\share\jupyter\kernels\python3

# %% [markdown]
# Last thing, go into the kernel.json file located in the C:\Users\mikem\AppData\Roaming\jupyter\kernels\py39_venv folder, update the path to the new environment as follows:

# %% [raw]
# {
#  "argv": [
#   "w:\\code\\wgu\\py39\\scripts\\python.exe",
#   "-m",
#   "ipykernel_launcher",
#   "-f",
#   "{connection_file}"
#  ],
#  "display_name": "py39_venv",
#  "language": "python",
#  "metadata": {
#   "debugger": true
#  }
# }
